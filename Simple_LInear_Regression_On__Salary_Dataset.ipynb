# %% [markdown]
# <a href="https://colab.research.google.com/github/GuptaShivam007/Simple-Linear-Regression-on-Salary-Data/blob/main/Simple_LInear_Regression_On__Salary_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the Dataset

# %%
data=pd.read_csv('Salary_Data.csv')

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# Splitting the dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# Building Simple Linear regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %% [markdown]
# Visulaizing the Training Set result

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Salary vs Years of Experience(Training Set)")
plt.xlabel("Years Of Experience")
plt.ylabel("Salary")
plt.grid()
plt.show()

# %% [markdown]
# Visualizing the Test Set result

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Salary Vs Experience(Test Set)")
plt.xlabel("Years Of Experience ")
plt.ylabel("Salary")
plt.grid()
plt.show()

# %% [markdown]
# Predicting the result of the single value

# %%
print(regressor.predict([[12]])) #predict method always expect the 2d array
# Out:
# [138531.00067138]

# %% [markdown]
# Finding the Coefficient and intercept of the model

# %%
print(regressor.coef_)
# Out:
# [9312.57512673]

# %%
print(regressor.intercept_)
# Out:
# 26780.09915062818
